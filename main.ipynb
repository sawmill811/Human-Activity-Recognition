# %%
import pandas as pd
import numpy as np
from scipy import linalg
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm
warnings.filterwarnings('ignore')

# %%
TRAIN = pd.read_csv('train.csv')
TEST = pd.read_csv('test.csv')

# %%
import re
TRAIN = TRAIN.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
TEST = TEST.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))

# %% [markdown]
# ## Exploratory Data Analysis

# %%
TRAIN
# Out:
#       tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0          0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1          0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2          0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3          0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4          0.276629      -0.016570      -0.115362     -0.998139     -0.980817
# ...             ...            ...            ...           ...           ...
# 7347       0.299665      -0.057193      -0.181233     -0.195387      0.039905
# 7348       0.273853      -0.007749      -0.147468     -0.235309      0.004816
# 7349       0.273387      -0.017011      -0.045022     -0.218218     -0.103822
# 7350       0.289654      -0.018843      -0.158281     -0.219139     -0.111412
# 7351       0.351503      -0.012423      -0.203867     -0.269270     -0.087212
#
#       tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  \
# 0        -0.913526     -0.995112     -0.983185     -0.923527     -0.934724
# 1        -0.960322     -0.998807     -0.974914     -0.957686     -0.943068
# 2        -0.978944     -0.996520     -0.963668     -0.977469     -0.938692
# 3        -0.990675     -0.997099     -0.982750     -0.989302     -0.938692
# 4        -0.990482     -0.998321     -0.979672     -0.990441     -0.942469
# ...            ...           ...           ...           ...           ...
# 7347      0.077078     -0.282301      0.043616      0.060410      0.210795
# 7348      0.059280     -0.322552     -0.029456      0.080585      0.117440
# 7349      0.274533     -0.304515     -0.098913      0.332584      0.043999
# 7350      0.268893     -0.310487     -0.068200      0.319473      0.101702
# 7351      0.177404     -0.377404     -0.038678      0.229430      0.269013
#
#       ...  fBodyBodyGyroJerkMagkurtosis  angletBodyAccMeangravity  \
# 0     ...                     -0.710304                 -0.112754
# 1     ...                     -0.861499                  0.053477
# 2     ...                     -0.760104                 -0.118559
# 3     ...                     -0.482845                 -0.036788
# 4     ...                     -0.699205                  0.123320
# ...   ...                           ...                       ...
# 7347  ...                     -0.880324                 -0.190437
# 7348  ...                     -0.680744                  0.064907
# 7349  ...                     -0.304029                  0.052806
# 7350  ...                     -0.344314                 -0.101360
# 7351  ...                     -0.740738                 -0.280088
#
#       angletBodyAccJerkMeangravityMean  angletBodyGyroMeangravityMean  \
# 0                             0.030400                      -0.464761
# 1                            -0.007435                      -0.732626
# 2                             0.177899                       0.100699
# 3                            -0.012892                       0.640011
# 4                             0.122542                       0.693578
# ...                                ...                            ...
# 7347                          0.829718                       0.206972
# 7348                          0.875679                      -0.879033
# 7349                         -0.266724                       0.864404
# 7350                          0.700740                       0.936674
# 7351                         -0.007739                      -0.056088
#
#       angletBodyGyroJerkMeangravityMean  angleXgravityMean  angleYgravityMean  \
# 0                             -0.018446          -0.841247           0.179941
# 1                              0.703511          -0.844788           0.180289
# 2                              0.808529          -0.848933           0.180637
# 3                             -0.485366          -0.848649           0.181935
# 4                             -0.615971          -0.847865           0.185151
# ...                                 ...                ...                ...
# 7347                          -0.425619          -0.791883           0.238604
# 7348                           0.400219          -0.771840           0.252676
# 7349                           0.701169          -0.779133           0.249145
# 7350                          -0.589479          -0.785181           0.246432
# 7351                          -0.616956          -0.783267           0.246809
#
#       angleZgravityMean  subject          Activity
# 0             -0.058627        1          STANDING
# 1             -0.054317        1          STANDING
# 2             -0.049118        1          STANDING
# 3             -0.047663        1          STANDING
# 4             -0.043892        1          STANDING
# ...                 ...      ...               ...
# 7347           0.049819       30  WALKING_UPSTAIRS
# 7348           0.050053       30  WALKING_UPSTAIRS
# 7349           0.040811       30  WALKING_UPSTAIRS
# 7350           0.025339       30  WALKING_UPSTAIRS
# 7351           0.036695       30  WALKING_UPSTAIRS
#
# [7352 rows x 563 columns]

# %%
TRAIN.isnull().sum()
# Out:
# tBodyAccmeanX        0
# tBodyAccmeanY        0
# tBodyAccmeanZ        0
# tBodyAccstdX         0
# tBodyAccstdY         0
#                     ..
# angleXgravityMean    0
# angleYgravityMean    0
# angleZgravityMean    0
# subject              0
# Activity             0
# Length: 563, dtype: int64

# %% [markdown]
# No Null values

# %%
TRAIN.describe()
# Out:
#        tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  \
# count    7352.000000    7352.000000    7352.000000   7352.000000
# mean        0.274488      -0.017695      -0.109141     -0.605438
# std         0.070261       0.040811       0.056635      0.448734
# min        -1.000000      -1.000000      -1.000000     -1.000000
# 25%         0.262975      -0.024863      -0.120993     -0.992754
# 50%         0.277193      -0.017219      -0.108676     -0.946196
# 75%         0.288461      -0.010783      -0.097794     -0.242813
# max         1.000000       1.000000       1.000000      1.000000
#
#        tBodyAccstdY  tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  \
# count   7352.000000   7352.000000   7352.000000   7352.000000   7352.000000
# mean      -0.510938     -0.604754     -0.630512     -0.526907     -0.606150
# std        0.502645      0.418687      0.424073      0.485942      0.414122
# min       -0.999873     -1.000000     -1.000000     -1.000000     -1.000000
# 25%       -0.978129     -0.980233     -0.993591     -0.978162     -0.980251
# 50%       -0.851897     -0.859365     -0.950709     -0.857328     -0.857143
# 75%       -0.034231     -0.262415     -0.292680     -0.066701     -0.265671
# max        0.916238      1.000000      1.000000      0.967664      1.000000
#
#        tBodyAccmaxX  ...  fBodyBodyGyroJerkMagskewness  \
# count   7352.000000  ...                   7352.000000
# mean      -0.468604  ...                     -0.307009
# std        0.544547  ...                      0.321011
# min       -1.000000  ...                     -0.995357
# 25%       -0.936219  ...                     -0.542602
# 50%       -0.881637  ...                     -0.343685
# 75%       -0.017129  ...                     -0.126979
# max        1.000000  ...                      0.989538
#
#        fBodyBodyGyroJerkMagkurtosis  angletBodyAccMeangravity  \
# count                   7352.000000               7352.000000
# mean                      -0.625294                  0.008684
# std                        0.307584                  0.336787
# min                       -0.999765                 -0.976580
# 25%                       -0.845573                 -0.121527
# 50%                       -0.711692                  0.009509
# 75%                       -0.503878                  0.150865
# max                        0.956845                  1.000000
#
#        angletBodyAccJerkMeangravityMean  angletBodyGyroMeangravityMean  \
# count                       7352.000000                    7352.000000
# mean                           0.002186                       0.008726
# std                            0.448306                       0.608303
# min                           -1.000000                      -1.000000
# 25%                           -0.289549                      -0.482273
# 50%                            0.008943                       0.008735
# 75%                            0.292861                       0.506187
# max                            1.000000                       0.998702
#
#        angletBodyGyroJerkMeangravityMean  angleXgravityMean  \
# count                        7352.000000        7352.000000
# mean                           -0.005981          -0.489547
# std                             0.477975           0.511807
# min                            -1.000000          -1.000000
# 25%                            -0.376341          -0.812065
# 50%                            -0.000368          -0.709417
# 75%                             0.359368          -0.509079
# max                             0.996078           1.000000
#
#        angleYgravityMean  angleZgravityMean      subject
# count        7352.000000        7352.000000  7352.000000
# mean            0.058593          -0.056515    17.413085
# std             0.297480           0.279122     8.975143
# min            -1.000000          -1.000000     1.000000
# 25%            -0.017885          -0.143414     8.000000
# 50%             0.182071           0.003181    19.000000
# 75%             0.248353           0.107659    26.000000
# max             0.478157           1.000000    30.000000
#
# [8 rows x 562 columns]

# %%
train = TRAIN.drop(['subject'], axis=1)

TRAINX = train.drop(['Activity'], axis=1)

LE = LabelEncoder()
TRAINY = LE.fit_transform(train['Activity'])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(TRAINX)
# Out:
# StandardScaler()

# %%
TRAINX = pd.DataFrame(scaler.transform(TRAINX), columns=TRAINX.columns)
TRAINX
# Out:
#       tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0          0.200642      -0.063683      -0.419628     -0.868814     -0.939441
# 1          0.055948       0.031486      -0.253908     -0.875426     -0.923902
# 2          0.073515      -0.043416      -0.076295     -0.869039     -0.907760
# 3          0.066696      -0.208422      -0.249712     -0.870626     -0.940022
# 4          0.030469       0.027587      -0.109848     -0.875188     -0.934878
# ...             ...            ...            ...           ...           ...
# 7347       0.358361      -0.967904      -1.273005      0.913859      1.095963
# 7348      -0.009044       0.243731      -0.676787      0.824887      1.026150
# 7349      -0.015668       0.016781       1.132221      0.862975      0.810002
# 7350       0.215866      -0.028123      -0.867710      0.860922      0.794902
# 7351       1.096202       0.129199      -1.672681      0.749198      0.843051
#
#       tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  \
# 0        -0.737529     -0.859817     -0.939019     -0.766437     -0.856036
# 1        -0.849304     -0.868531     -0.921998     -0.848928     -0.871359
# 2        -0.893785     -0.863137     -0.898854     -0.896701     -0.863323
# 3        -0.921805     -0.864503     -0.938124     -0.925279     -0.863323
# 4        -0.921343     -0.867384     -0.931789     -0.928028     -0.870260
# ...            ...           ...           ...           ...           ...
# 7347      1.628612      0.821169      1.174137      1.609686      1.247727
# 7348      1.586100      0.726245      1.023755      1.658407      1.076279
# 7349      2.100249      0.768781      0.880813      2.266963      0.941403
# 7350      2.086778      0.754697      0.944019      2.235301      1.047375
# 7351      1.868249      0.596891      1.004776      2.017853      1.354644
#
#       ...  fBodyBodyGyroJerkMagmeanFreq  fBodyBodyGyroJerkMagskewness  \
# 0     ...                     -0.795359                      0.025960
# 1     ...                      0.130614                     -0.897357
# 2     ...                      1.152336                     -0.260878
# 3     ...                      1.112769                      0.591045
# 4     ...                     -0.149577                     -0.138515
# ...   ...                           ...                           ...
# 7347  ...                     -0.778758                     -0.876738
# 7348  ...                      0.159241                     -0.260847
# 7349  ...                      0.277877                      1.034784
# 7350  ...                     -0.443978                      1.155541
# 7351  ...                     -0.731921                     -0.249363
#
#       fBodyBodyGyroJerkMagkurtosis  angletBodyAccMeangravity  \
# 0                        -0.276399                 -0.360603
# 1                        -0.767990                  0.133011
# 2                        -0.438316                 -0.377840
# 3                         0.463155                 -0.135025
# 4                        -0.240313                  0.340406
# ...                            ...                       ...
# 7347                     -0.829197                 -0.591277
# 7348                     -0.180290                  0.166951
# 7349                      1.044548                  0.131018
# 7350                      0.913569                 -0.326769
# 7351                     -0.375352                 -0.857491
#
#       angletBodyAccJerkMeangravityMean  angletBodyGyroMeangravityMean  \
# 0                             0.062940                      -0.778427
# 1                            -0.021461                      -1.218805
# 2                             0.391976                       0.151207
# 3                            -0.033637                       1.037851
# 4                             0.268486                       1.125918
# ...                                ...                            ...
# 7347                          1.846034                       0.325923
# 7348                          1.948561                      -1.459501
# 7349                         -0.599877                       1.406760
# 7350                          1.558312                       1.525574
# 7351                         -0.022141                      -0.106555
#
#       angletBodyGyroJerkMeangravityMean  angleXgravityMean  angleYgravityMean  \
# 0                             -0.026080          -0.687219           0.407946
# 1                              1.484470          -0.694138           0.409117
# 2                              1.704201          -0.702239           0.410288
# 3                             -1.003019          -0.701684           0.414650
# 4                             -1.276282          -0.700152           0.425463
# ...                                 ...                ...                ...
# 7347                          -0.878008          -0.590763           0.605162
# 7348                           0.849894          -0.551598           0.652468
# 7349                           1.479571          -0.565848           0.640597
# 7350                          -1.220854          -0.577668           0.631478
# 7351                          -1.278345          -0.573927           0.632743
#
#       angleZgravityMean
# 0             -0.007568
# 1              0.007875
# 2              0.026502
# 3              0.031714
# 4              0.045225
# ...                 ...
# 7347           0.380984
# 7348           0.381820
# 7349           0.348709
# 7350           0.293276
# 7351           0.333961
#
# [7352 rows x 561 columns]

# %% [markdown]
# This is a very high dimensional data, so we should try Dimensionality Reduction.

# %% [markdown]
# #### PCA

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(TRAINX)

cum_var_ratio = np.cumsum(pca.explained_variance_ratio_)

plt.figure(figsize=(10,5))
plt.plot(cum_var_ratio)
plt.title("PCA Results")
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance Ratio")
plt.show()

# %% [markdown]
# If we will apply PCA then about 100 to 150 principal components will be sufficient to model the given data.

# %% [markdown]
# If we attempt to visualise the data using the first two Principal Components

# %%
pca = PCA(n_components=2)
pca.fit(TRAINX, TRAINY)
pcaX = pd.DataFrame(pca.transform(TRAINX), columns=['PC1', 'PC2'])
pcaY = LE.inverse_transform(TRAINY)
plt.figure(figsize=(10,7))
sns.scatterplot(x='PC1', y='PC2', hue=pcaY, data=pcaX, palette=["red","cyan","green","purple","black","yellow"])
plt.title("Transformed Training Data after Principal Component Analysis") 
plt.show()

# %% [markdown]
# This scatter plot isn't very helpful since the clusters are not distinct. Hence, using 2 PC's for visualisation won't work for us.

# %% [markdown]
# #### LDA

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA()
lda.fit(TRAINX, TRAINY)

cum_var_ratio = np.cumsum(lda.explained_variance_ratio_)

plt.figure(figsize=(10,5))
plt.plot(range(1,len(cum_var_ratio)+1), cum_var_ratio, '*-')
plt.title("LDA Results")
plt.xlabel("Linear Discriminants")
plt.ylabel("Ciumulative Explained Variance Ratio")
plt.xticks(range(1,len(cum_var_ratio)+1))
plt.show()

# %% [markdown]
# The best 2 Linear Discriminants (LD's) are able to explain > 90% variance of the data. So we can attempt to visualise the data using these two LD's.

# %%
lda = LDA(n_components=2)
lda.fit(TRAINX, TRAINY)
ldaX = pd.DataFrame(lda.transform(TRAINX), columns=['LD1', 'LD2'])
ldaY = LE.inverse_transform(TRAINY)
plt.figure(figsize=(15,9))
sns.scatterplot(x='LD1', y='LD2', hue=ldaY, data=ldaX, palette=["red","cyan","green","purple","black","yellow"])
# plt.legend(LE.classes_)
plt.title("Transformed Training Data after Linear Discriminant Analysis") 
plt.show()

# %% [markdown]
# The above data visualisation looks promising with distinct clusters being formed.

# %% [markdown]
# ### Train-Validation Split

# %%
from sklearn.model_selection import train_test_split as tts
trainX, valX, trainY, valY = tts(TRAINX, TRAINY, test_size=0.2, random_state=42, stratify = TRAINY)

# %% [markdown]
# ## Testing Models

# %% [markdown]
# ### Imports

# %%
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as QDA
from xgboost import XGBClassifier as XGBC

from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ### LDA

# %%
lda = LDA(store_covariance=True)
lda.fit(trainX, trainY)
pred = lda.predict(valX)
print("Accuracy:", str(np.around(accuracy_score(valY, pred), decimals=4)*100)+"%")
print("Classification Report:\n",classification_report(valY, pred, target_names=LE.classes_))
print("**The above metrics are evaluated on the Validation Dataset")
# Out:
# Accuracy: 98.3%
# Classification Report:
#                      precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       282
#            SITTING       0.94      0.98      0.96       257
#           STANDING       0.98      0.94      0.96       275
#            WALKING       1.00      1.00      1.00       245
# WALKING_DOWNSTAIRS       1.00      0.99      1.00       197
#   WALKING_UPSTAIRS       1.00      1.00      1.00       215
#
#           accuracy                           0.98      1471
#          macro avg       0.98      0.98      0.98      1471
#       weighted avg       0.98      0.98      0.98      1471
#
# **The above metrics are evaluated on the Validation Dataset

# %% [markdown]
# ### QDA

# %%
qda = QDA(store_covariance=True)
qda.fit(trainX, trainY)
pred = qda.predict(valX)
print("Accuracy:", str(np.around(accuracy_score(valY, pred), decimals=5)*100)+"%")
print("Classification Report:\n",classification_report(valY, pred, target_names=LE.classes_))
print("**The above metrics are evaluated on the Validation Dataset")
# Out:
# Accuracy: 94.018%
# Classification Report:
#                      precision    recall  f1-score   support
#
#             LAYING       0.99      1.00      1.00       282
#            SITTING       0.94      0.83      0.88       257
#           STANDING       0.88      0.91      0.89       275
#            WALKING       0.97      0.98      0.98       245
# WALKING_DOWNSTAIRS       0.92      0.96      0.94       197
#   WALKING_UPSTAIRS       0.93      0.97      0.95       215
#
#           accuracy                           0.94      1471
#          macro avg       0.94      0.94      0.94      1471
#       weighted avg       0.94      0.94      0.94      1471
#
# **The above metrics are evaluated on the Validation Dataset

# %% [markdown]
# ### RFC

# %%
# from sklearn.model_selection import GridSearchCV
# parameters = {'max_depth':[5,10,12,14,16,18,20,22,24,26], 'n_estimators':[50,100,150,200], 'min_samples_split':[10,20,30,40,50]}
# rfc = RFC()
# clf = GridSearchCV(rfc, parameters, cv=5, n_jobs = -1, verbose = 2)
# clf.fit(TRAINX, TRAINY)
# best_model = clf.best_estimator_
# print("Best RandomForestClassifier after GridSearchCV:", best_model)
# print("Best parameters:", clf.best_params_)

# %%
best_model = RFC(max_depth = 20, n_estimators = 500, min_samples_split = 2)     # After playing with a few parameters
best_model.fit(trainX, trainY)
pred = best_model.predict(valX)
print("Accuracy using best parameters", str(np.around(accuracy_score(valY, pred), decimals=4)*100)+"%")
print("Classification Report:\n", classification_report(valY, pred, target_names=LE.classes_))
print("**The above metrics are evaluated on the Validation Dataset")
# Out:
# Accuracy using best parameters 98.71%
# Classification Report:
#                      precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       282
#            SITTING       0.99      0.96      0.97       257
#           STANDING       0.96      0.99      0.98       275
#            WALKING       1.00      0.99      0.99       245
# WALKING_DOWNSTAIRS       0.98      0.99      0.98       197
#   WALKING_UPSTAIRS       0.99      1.00      0.99       215
#
#           accuracy                           0.99      1471
#          macro avg       0.99      0.99      0.99      1471
#       weighted avg       0.99      0.99      0.99      1471
#
# **The above metrics are evaluated on the Validation Dataset

# %% [markdown]
# ### XGboostClassifier

# %%
# from sklearn.model_selection import GridSearchCV
# parameters = {'max_depth':[5,10], 'eta':[0.01,0.1], 'subsample':[0.4,0.5]}
# xgb = XGBC(tree_method = "gpu_hist")
# clf = GridSearchCV(xgb, parameters, cv=5, n_jobs = -1, verbose = 2)
# clf.fit(TRAINX, TRAINY)
# best_model = clf.best_estimator_
# print("Best XGBoostClassifier after GridSearchCV:", best_model)

# %% [markdown]
# The above `GridSearchCV` takes about 18 minutes to run.

# %%
acc_list_train = []
acc_list_val = []
for i in tqdm(range(100,801,100)):
    xgb = XGBC(verbosity = 0, n_estimators = i, max_depth = 5, eta = 0.1, tree_method = "gpu_hist", subsample = 0.3, random_state=42) 
    xgb.fit(trainX, trainY)
    pred = xgb.predict(valX)
    acc_list_val.append(accuracy_score(valY, pred))
    pred = xgb.predict(trainX)
    acc_list_train.append(accuracy_score(trainY, pred))
    print("Number of Estimators:", i, "Accuracy:", str(np.around(accuracy_score(valY, pred), decimals=4)*100)+"%")
# Out:
#   0%|          | 0/8 [00:08<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\My Stuff\GitHub Repos\Human-Activity-Recognition\main.ipynb Cell 39' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/My%20Stuff/GitHub%20Repos/Human-Activity-Recognition/main.ipynb#ch0000038?line=7'>8</a> pred = xgb.predict(trainX)
#       <a href='vscode-notebook-cell:/d%3A/My%20Stuff/GitHub%20Repos/Human-Activity-Recognition/main.ipynb#ch0000038?line=8'>9</a> acc_list_train.append(accuracy_score(trainY, pred))
# ---> <a href='vscode-notebook-cell:/d%3A/My%20Stuff/GitHub%20Repos/Human-Activity-Recognition/main.ipynb#ch0000038?line=9'>10</a> print("Number of Estimators:", i, "Accuracy:", str(np.around(accuracy_score(valY, pred), decimals=4)*100)+"%")
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:211, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=144'>145</a> """Accuracy classification score.
#     <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=145'>146</a>
#     <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=146'>147</a> In multilabel classification, this function computes subset accuracy:
#    (...)
#     <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=206'>207</a> 0.5
#     <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=207'>208</a> """
#     <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=209'>210</a> # Compute accuracy for each possible representation
# --> <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=210'>211</a> y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=211'>212</a> check_consistent_length(y_true, y_pred, sample_weight)
#     <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=212'>213</a> if y_type.startswith("multilabel"):
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:84, in _check_targets(y_true, y_pred)
#      <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=56'>57</a> def _check_targets(y_true, y_pred):
#      <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=57'>58</a>     """Check that y_true and y_pred belong to the same classification task.
#      <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=58'>59</a>
#      <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=59'>60</a>     This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=81'>82</a>     y_pred : array or indicator matrix
#      <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=82'>83</a>     """
# ---> <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=83'>84</a>     check_consistent_length(y_true, y_pred)
#      <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=84'>85</a>     type_true = type_of_target(y_true)
#      <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/metrics/_classification.py?line=85'>86</a>     type_pred = type_of_target(y_pred)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\utils\validation.py:332, in check_consistent_length(*arrays)
#     <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/utils/validation.py?line=329'>330</a> uniques = np.unique(lengths)
#     <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/utils/validation.py?line=330'>331</a> if len(uniques) > 1:
# --> <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/utils/validation.py?line=331'>332</a>     raise ValueError(
#     <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/utils/validation.py?line=332'>333</a>         "Found input variables with inconsistent numbers of samples: %r"
#     <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/utils/validation.py?line=333'>334</a>         % [int(l) for l in lengths]
#     <a href='file:///c%3A/Users/soumi/AppData/Local/Programs/Python/Python38/lib/site-packages/sklearn/utils/validation.py?line=334'>335</a>     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1471, 5881]

# %%
plt.figure(figsize=(10,5))
plt.plot(range(100,801,100), acc_list_train, 'r*-', label = "Train Accuracy")
plt.plot(range(100,801,100), acc_list_val, 'b*-', label = "Validation Accuracy")
plt.title("XGBoost Accuracy vs Number of Estimators")
plt.xlabel("Number of Estimators")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# 200 estimators should be good enough

# %%
acc_list_train = []
acc_list_val = []
for i in tqdm(range(4,20)):
    xgb = XGBC(verbosity = 0, n_estimators = 200, max_depth = i, eta = 0.1, tree_method = "gpu_hist", subsample = 0.3, random_state=42) 
    xgb.fit(trainX, trainY)
    pred = xgb.predict(trainX)
    acc_list_train.append(accuracy_score(trainY, pred))
    pred = xgb.predict(valX)
    acc_list_val.append(accuracy_score(valY, pred))
    print("Max Depth:", i, "Validation Accuracy:", str(np.around(accuracy_score(valY, pred), decimals=4)*100)+"%")
# Out:
#   6%|▋         | 1/16 [00:10<02:42, 10.85s/it]
# Max Depth: 4 Validation Accuracy: 99.32%
#  12%|█▎        | 2/16 [00:23<02:47, 12.00s/it]
# Max Depth: 5 Validation Accuracy: 99.46000000000001%
#  19%|█▉        | 3/16 [00:38<02:52, 13.26s/it]
# Max Depth: 6 Validation Accuracy: 99.32%
#  25%|██▌       | 4/16 [00:54<02:50, 14.24s/it]
# Max Depth: 7 Validation Accuracy: 99.39%
#  31%|███▏      | 5/16 [01:10<02:43, 14.90s/it]
# Max Depth: 8 Validation Accuracy: 99.39%
#  38%|███▊      | 6/16 [01:27<02:37, 15.77s/it]
# Max Depth: 9 Validation Accuracy: 99.46000000000001%
#  44%|████▍     | 7/16 [01:45<02:27, 16.44s/it]
# Max Depth: 10 Validation Accuracy: 99.32%
#  50%|█████     | 8/16 [02:03<02:15, 16.91s/it]
# Max Depth: 11 Validation Accuracy: 99.25%
#  56%|█████▋    | 9/16 [02:21<02:00, 17.26s/it]
# Max Depth: 12 Validation Accuracy: 99.32%
#  62%|██████▎   | 10/16 [02:39<01:45, 17.54s/it]
# Max Depth: 13 Validation Accuracy: 99.39%
#  69%|██████▉   | 11/16 [02:58<01:29, 17.80s/it]
# Max Depth: 14 Validation Accuracy: 99.18%
#  75%|███████▌  | 12/16 [03:16<01:11, 18.00s/it]
# Max Depth: 15 Validation Accuracy: 99.32%
#  81%|████████▏ | 13/16 [03:35<00:54, 18.22s/it]
# Max Depth: 16 Validation Accuracy: 99.39%
#  88%|████████▊ | 14/16 [03:53<00:36, 18.39s/it]
# Max Depth: 17 Validation Accuracy: 99.25%
#  94%|█████████▍| 15/16 [04:13<00:18, 18.73s/it]
# Max Depth: 18 Validation Accuracy: 99.46000000000001%
# 100%|██████████| 16/16 [04:34<00:00, 17.16s/it]
# Max Depth: 19 Validation Accuracy: 99.46000000000001%

# %%
plt.figure(figsize=(10,5))
plt.plot(range(4,20), acc_list_train, 'r*-', label = "Train Accuracy")
plt.plot(range(4,20), acc_list_val, 'b*-', label = "Validation Accuracy")
plt.title("XGBoost Accuracy vs Max Depth")
plt.xlabel("Max Depth")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# Best model
xgb = XGBC(verbosity = 0, n_estimators = 200, max_depth = 5, eta = 0.1, tree_method = "gpu_hist", subsample = 0.3, random_state=42) 
xgb.fit(trainX, trainY)
pred = xgb.predict(valX)
print("Accuracy:", str(np.around(accuracy_score(valY, pred), decimals=4)*100)+"%")
print("Classification Report:\n", classification_report(valY, pred, target_names=LE.classes_))
print("**The above metrics are evaluated on the Validation Dataset")
# Out:
# Accuracy: 99.46000000000001%
# Classification Report:
#                      precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       282
#            SITTING       0.99      0.98      0.98       257
#           STANDING       0.98      0.99      0.99       275
#            WALKING       1.00      1.00      1.00       245
# WALKING_DOWNSTAIRS       1.00      1.00      1.00       197
#   WALKING_UPSTAIRS       1.00      1.00      1.00       215
#
#           accuracy                           0.99      1471
#          macro avg       1.00      0.99      0.99      1471
#       weighted avg       0.99      0.99      0.99      1471
#
# **The above metrics are evaluated on the Validation Dataset

# %% [markdown]
# ### LightGBMClassifier

# %%
import lightgbm as lgb

acc_list_train = []
acc_list_val = []

for md in range(4,20):
    lc = lgb.LGBMClassifier(learning_rate = 0.01, max_depth = md)
    lc.fit(trainX, trainY)
    pred = lc.predict(trainX)
    acc_list_val.append(accuracy_score(trainY, pred))
    pred = lc.predict(valX)
    acc_list_val.append(accuracy_score(valY, pred))
    print("Max Depth:", md, "Validation Accuracy:", str(np.around(accuracy_score(valY, pred), decimals=4)*100)+"%")
# Out:
# Max Depth: 4 Validation Accuracy: 95.92%
# Max Depth: 5 Validation Accuracy: 97.08%
# Max Depth: 6 Validation Accuracy: 97.82%
# Max Depth: 7 Validation Accuracy: 98.1%
# Max Depth: 8 Validation Accuracy: 98.1%
# Max Depth: 9 Validation Accuracy: 98.22999999999999%
# Max Depth: 10 Validation Accuracy: 98.3%
# Max Depth: 11 Validation Accuracy: 98.3%
# Max Depth: 12 Validation Accuracy: 98.22999999999999%
# Max Depth: 13 Validation Accuracy: 98.3%

# %%
plt.figure(figsize=(10,5))
plt.plot(range(4,20), acc_list_val, 'b*-', label="Validation Accuracy")
plt.plot(range(4,20), acc_list_train, 'r*-', label="Train Accuracy")
plt.title("LightGBM Accuracy vs Number of Estimators")
plt.xlabel("Max Depth")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
lc = lgb.LGBMClassifier(learning_rate = 0.01, max_depth = 10)
lc.fit(trainX, trainY)
pred = lc.predict(valX)
print("Accuracy:", str(np.around(accuracy_score(valY, pred), decimals=4)*100)+"%")
print("Classification Report:\n", classification_report(valY, pred, target_names=LE.classes_))
print("**The above metrics are evaluated on the Validation Dataset")
# Out:
# Accuracy: 98.3%
# Classification Report:
#                      precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       282
#            SITTING       0.98      0.95      0.96       257
#           STANDING       0.95      0.98      0.97       275
#            WALKING       1.00      0.98      0.99       245
# WALKING_DOWNSTAIRS       0.98      0.99      0.99       197
#   WALKING_UPSTAIRS       0.99      1.00      0.99       215
#
#           accuracy                           0.98      1471
#          macro avg       0.98      0.98      0.98      1471
#       weighted avg       0.98      0.98      0.98      1471
#
# **The above metrics are evaluated on the Validation Dataset

# %% [markdown]
# ## Test Dataset

# %%
TEST
# Out:
#       tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0          0.257178      -0.023285      -0.014654     -0.938404     -0.920091
# 1          0.286027      -0.013163      -0.119083     -0.975415     -0.967458
# 2          0.275485      -0.026050      -0.118152     -0.993819     -0.969926
# 3          0.270298      -0.032614      -0.117520     -0.994743     -0.973268
# 4          0.274833      -0.027848      -0.129527     -0.993852     -0.967445
# ...             ...            ...            ...           ...           ...
# 2942       0.310155      -0.053391      -0.099109     -0.287866     -0.140589
# 2943       0.363385      -0.039214      -0.105915     -0.305388      0.028148
# 2944       0.349966       0.030077      -0.115788     -0.329638     -0.042143
# 2945       0.237594       0.018467      -0.096499     -0.323114     -0.229775
# 2946       0.153627      -0.018437      -0.137018     -0.330046     -0.195253
#
#       tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  \
# 0        -0.667683     -0.952501     -0.925249     -0.674302     -0.894088
# 1        -0.944958     -0.986799     -0.968401     -0.945823     -0.894088
# 2        -0.962748     -0.994403     -0.970735     -0.963483     -0.939260
# 3        -0.967091     -0.995274     -0.974471     -0.968897     -0.938610
# 4        -0.978295     -0.994111     -0.965953     -0.977346     -0.938610
# ...            ...           ...           ...           ...           ...
# 2942     -0.215088     -0.356083     -0.148775     -0.232057      0.185361
# 2943     -0.196373     -0.373540     -0.030036     -0.270237      0.185361
# 2944     -0.250181     -0.388017     -0.133257     -0.347029      0.007471
# 2945     -0.207574     -0.392380     -0.279610     -0.289477      0.007471
# 2946     -0.164339     -0.430974     -0.218295     -0.229933     -0.111527
#
#       ...  fBodyBodyGyroJerkMagkurtosis  angletBodyAccMeangravity  \
# 0     ...                     -0.705974                  0.006462
# 1     ...                     -0.594944                 -0.083495
# 2     ...                     -0.640736                 -0.034956
# 3     ...                     -0.736124                 -0.017067
# 4     ...                     -0.846595                 -0.002223
# ...   ...                           ...                       ...
# 2942  ...                     -0.750809                 -0.337422
# 2943  ...                     -0.700274                 -0.736701
# 2944  ...                     -0.467179                 -0.181560
# 2945  ...                     -0.617737                  0.444558
# 2946  ...                     -0.436940                  0.598808
#
#       angletBodyAccJerkMeangravityMean  angletBodyGyroMeangravityMean  \
# 0                             0.162920                      -0.825886
# 1                             0.017500                      -0.434375
# 2                             0.202302                       0.064103
# 3                             0.154438                       0.340134
# 4                            -0.040046                       0.736715
# ...                                ...                            ...
# 2942                          0.346295                       0.884904
# 2943                         -0.372889                      -0.657421
# 2944                          0.088574                       0.696663
# 2945                         -0.819188                       0.929294
# 2946                         -0.287951                       0.876030
#
#       angletBodyGyroJerkMeangravityMean  angleXgravityMean  angleYgravityMean  \
# 0                              0.271151          -0.720009           0.276801
# 1                              0.920593          -0.698091           0.281343
# 2                              0.145068          -0.702771           0.280083
# 3                              0.296407          -0.698954           0.284114
# 4                             -0.118545          -0.692245           0.290722
# ...                                 ...                ...                ...
# 2942                          -0.698885          -0.651732           0.274627
# 2943                           0.322549          -0.655181           0.273578
# 2944                           0.363139          -0.655357           0.274479
# 2945                          -0.008398          -0.659719           0.264782
# 2946                          -0.024965          -0.660080           0.263936
#
#       angleZgravityMean  subject          Activity
# 0             -0.057978        2          STANDING
# 1             -0.083898        2          STANDING
# 2             -0.079346        2          STANDING
# 3             -0.077108        2          STANDING
# 4             -0.073857        2          STANDING
# ...                 ...      ...               ...
# 2942           0.184784       24  WALKING_UPSTAIRS
# 2943           0.182412       24  WALKING_UPSTAIRS
# 2944           0.181184       24  WALKING_UPSTAIRS
# 2945           0.187563       24  WALKING_UPSTAIRS
# 2946           0.188103       24  WALKING_UPSTAIRS
#
# [2947 rows x 563 columns]

# %%
TEST.isnull().sum()
# Out:
# tBodyAccmeanX        0
# tBodyAccmeanY        0
# tBodyAccmeanZ        0
# tBodyAccstdX         0
# tBodyAccstdY         0
#                     ..
# angleXgravityMean    0
# angleYgravityMean    0
# angleZgravityMean    0
# subject              0
# Activity             0
# Length: 563, dtype: int64

# %% [markdown]
# No Null values

# %%
test = TEST.drop(['subject'], axis=1)

# %%
testX = test.drop(['Activity'], axis=1)
testY = LE.transform(test['Activity'])

# %%
testX = pd.DataFrame(scaler.transform(testX), columns=testX.columns)
testX
# Out:
#       tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0         -0.246388      -0.136979       1.668462     -0.742061     -0.814056
# 1          0.164235       0.111059      -0.175548     -0.824544     -0.908299
# 2          0.014187      -0.204740      -0.159111     -0.865561     -0.913208
# 3         -0.059637      -0.365579      -0.147960     -0.867620     -0.919858
# 4          0.004908      -0.248785      -0.359980     -0.865636     -0.908274
# ...             ...            ...            ...           ...           ...
# 2942       0.507661      -0.874731       0.177151      0.707754      0.736850
# 2943       1.265313      -0.527316       0.056964      0.668705      1.072571
# 2944       1.074319       1.170681      -0.117372      0.614660      0.932720
# 2945      -0.525137       0.886163       0.223235      0.629199      0.559404
# 2946      -1.720280      -0.018160      -0.492262      0.613751      0.628089
#
#       tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  \
# 0        -0.150313     -0.759330     -0.819786     -0.164580     -0.781407
# 1        -0.812607     -0.840212     -0.908595     -0.820280     -0.781407
# 2        -0.855099     -0.858146     -0.913397     -0.862926     -0.864367
# 3        -0.865472     -0.860199     -0.921086     -0.876002     -0.863173
# 4        -0.892234     -0.857457     -0.903555     -0.896405     -0.863173
# ...            ...           ...           ...           ...           ...
# 2942      0.930750      0.647171      0.778197      0.903402      1.201017
# 2943      0.975451      0.606004      1.022561      0.811203      1.201017
# 2944      0.846927      0.571863      0.810133      0.625756      0.874320
# 2945      0.948698      0.561574      0.508938      0.764738      0.874320
# 2946      1.051968      0.470561      0.635125      0.908533      0.655777
#
#       ...  fBodyBodyGyroJerkMagmeanFreq  fBodyBodyGyroJerkMagskewness  \
# 0     ...                     -0.213757                     -0.072779
# 1     ...                     -2.097734                      0.576855
# 2     ...                     -0.248637                      0.363213
# 3     ...                     -0.034259                     -0.116542
# 4     ...                     -0.984174                     -0.709294
# ...   ...                           ...                           ...
# 2942  ...                     -0.202496                     -0.215797
# 2943  ...                     -0.093371                     -0.041773
# 2944  ...                     -0.763187                      0.586175
# 2945  ...                     -0.684366                      0.316410
# 2946  ...                     -0.540605                      0.731402
#
#       fBodyBodyGyroJerkMagkurtosis  angletBodyAccMeangravity  \
# 0                        -0.262320                 -0.006596
# 1                         0.098679                 -0.273719
# 2                        -0.050207                 -0.129586
# 3                        -0.360349                 -0.076465
# 4                        -0.719531                 -0.032386
# ...                            ...                       ...
# 2942                     -0.408096                 -1.027739
# 2943                     -0.243789                 -2.213376
# 2944                      0.514088                 -0.564919
# 2945                      0.024572                  1.294302
# 2946                      0.612407                  1.752340
#
#       angletBodyAccJerkMeangravityMean  angletBodyGyroMeangravityMean  \
# 0                             0.358560                      -1.372126
# 1                             0.034161                      -0.728470
# 2                             0.446413                       0.091042
# 3                             0.339639                       0.544845
# 4                            -0.094211                       1.196836
# ...                                ...                            ...
# 2942                          0.767627                       1.440462
# 2943                         -0.836706                      -1.095164
# 2944                          0.192712                       1.130990
# 2945                         -1.832296                       1.513441
# 2946                         -0.647228                       1.425873
#
#       angletBodyGyroJerkMeangravityMean  angleXgravityMean  angleYgravityMean  \
# 0                              0.579845          -0.450322           0.733571
# 1                              1.938673          -0.407493           0.748840
# 2                              0.316041          -0.416639           0.744605
# 3                              0.632687          -0.409180           0.758155
# 4                             -0.235517          -0.396070           0.780371
# ...                                 ...                ...                ...
# 2942                          -1.449764          -0.316909           0.726262
# 2943                           0.687383          -0.323647           0.722737
# 2944                           0.772310          -0.323991           0.725764
# 2945                          -0.005058          -0.332514           0.693165
# 2946                          -0.039721          -0.333221           0.690322
#
#       angleZgravityMean
# 0             -0.005244
# 1             -0.098112
# 2             -0.081803
# 3             -0.073784
# 4             -0.062135
# ...                 ...
# 2942           0.864551
# 2943           0.856052
# 2944           0.851650
# 2945           0.874507
# 2946           0.876443
#
# [2947 rows x 561 columns]

# %% [markdown]
# ### Testing Models on Test Dataset

# %%
xgb = XGBC(n_estimators = 500, max_depth = 5, eta = 0.1, tree_method = "gpu_hist", subsample = 0.3, random_state=42) 
xgb.fit(trainX, trainY)
pred = xgb.predict(testX)
print("Accuracy on Test Dataset:", str(np.around(accuracy_score(testY, pred), decimals=4)*100)+"%")
print("Classification Report:\n", classification_report(testY, pred, target_names=LE.classes_))
print("**The above metrics are evaluated on the Test Dataset")
# Out:
# Accuracy on Test Dataset: 95.59%
# Classification Report:
#                      precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.96      0.90      0.93       491
#           STANDING       0.92      0.96      0.94       532
#            WALKING       0.94      0.99      0.96       496
# WALKING_DOWNSTAIRS       0.98      0.94      0.96       420
#   WALKING_UPSTAIRS       0.94      0.93      0.94       471
#
#           accuracy                           0.96      2947
#          macro avg       0.96      0.95      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947
#
# **The above metrics are evaluated on the Test Dataset

# %%
lc = lgb.LGBMClassifier(learning_rate = 0.01, max_depth = 10)
lc.fit(trainX, trainY)
pred = lc.predict(testX)
print("Accuracy on Test Dataset:", str(np.around(accuracy_score(testY, pred), decimals=4)*100)+"%")
print("Classification Report:\n", classification_report(testY, pred, target_names=LE.classes_))
print("**The above metrics are evaluated on the Test Dataset")
# Out:
# Accuracy on Test Dataset: 90.13%
# Classification Report:
#                      precision    recall  f1-score   support
#
#             LAYING       0.99      1.00      1.00       537
#            SITTING       0.88      0.81      0.84       491
#           STANDING       0.84      0.89      0.87       532
#            WALKING       0.87      0.95      0.91       496
# WALKING_DOWNSTAIRS       0.92      0.90      0.91       420
#   WALKING_UPSTAIRS       0.91      0.84      0.88       471
#
#           accuracy                           0.90      2947
#          macro avg       0.90      0.90      0.90      2947
#       weighted avg       0.90      0.90      0.90      2947
#
# **The above metrics are evaluated on the Test Dataset
